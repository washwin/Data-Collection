# %%
# !pip install twikit
# Out:
# Collecting twikit
#   Downloading twikit-1.2.1-py3-none-any.whl.metadata (3.6 kB)
# Collecting httpx (from twikit)
#   Downloading httpx-0.27.0-py3-none-any.whl.metadata (7.2 kB)
# Collecting fake-useragent (from twikit)
#   Downloading fake_useragent-1.4.0-py3-none-any.whl.metadata (13 kB)
# Collecting anyio (from httpx->twikit)
#   Downloading anyio-4.3.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting certifi (from httpx->twikit)
#   Using cached certifi-2024.2.2-py3-none-any.whl.metadata (2.2 kB)
# Collecting httpcore==1.* (from httpx->twikit)
#   Downloading httpcore-1.0.4-py3-none-any.whl.metadata (20 kB)
# Collecting idna (from httpx->twikit)
#   Using cached idna-3.6-py3-none-any.whl.metadata (9.9 kB)
# Collecting sniffio (from httpx->twikit)
#   Downloading sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx->twikit)
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Downloading twikit-1.2.1-py3-none-any.whl (59 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.7/59.7 kB 670.4 kB/s eta 0:00:00a 0:00:01
# Downloading fake_useragent-1.4.0-py3-none-any.whl (15 kB)
# Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 451.2 kB/s eta 0:00:00a 0:00:01
# Downloading httpcore-1.0.4-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.8/77.8 kB 482.3 kB/s eta 0:00:00a 0:00:01
# Downloading anyio-4.3.0-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.6/85.6 kB 556.6 kB/s eta 0:00:00a 0:00:01
# Using cached idna-3.6-py3-none-any.whl (61 kB)
# Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Using cached certifi-2024.2.2-py3-none-any.whl (163 kB)
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 2.1 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: fake-useragent, sniffio, idna, h11, certifi, httpcore, anyio, httpx, twikit
# Successfully installed anyio-4.3.0 certifi-2024.2.2 fake-useragent-1.4.0 h11-0.14.0 httpcore-1.0.4 httpx-0.27.0 idna-3.6 sniffio-1.3.1 twikit-1.2.1

# %%
from twikit import Client
import csv
import time
import twikit

# %%
USERNAME = 'DataC51466'
EMAIL = 'xxxxxxxxxxxxxxxx'
PASSWORD = 'xxxxxx'
# Initialize client
client = Client('en-US')
# Login to the service with provided user credentials
client.login(
    auth_info_1=USERNAME ,
    auth_info_2=EMAIL,
    password=PASSWORD
)
# Out:
# {'flow_token': 'g;170997613707434596:-1709976137376:05zZLMZQwOzNlMVuSH8zLxGb:14',
#  'status': 'success',
#  'subtasks': [{'subtask_id': 'LoginSuccessSubtask',
#    'open_account': {'user': {'id': 1766078927519510528,
#      'id_str': '1766078927519510528',
#      'name': 'data-collection',
#      'screen_name': 'DataC51466'},
#     'next_link': {'link_type': 'subtask',
#      'link_id': 'next_link',
#      'subtask_id': 'SuccessExit'},
#     'attribution_event': 'login'}},
#   {'subtask_id': 'SuccessExit',
#    'open_link': {'link': {'link_type': 'subtask',
#      'link_id': 'next_link',
#      'subtask_id': 'LoginOpenHomeTimeline'}}},
#   {'subtask_id': 'LoginOpenHomeTimeline',
#    'open_home_timeline': {'next_link': {'link_type': 'abort',
#      'link_id': 'next_link'}}}]}

# %%
tweets = client.search_tweet('Manipur', 'Latest')
for tweet_id in tweets:
    print(tweet_id)
# Search more tweets
more_tweets = tweets.next()
for tweet_id in more_tweets:
    print(tweet_id)
# Out:
# <Tweet id="1766083001224683683">
# <Tweet id="1766082994874269708">
# <Tweet id="1766082844911395226">
# <Tweet id="1766082803937247658">
# <Tweet id="1766082676123939234">
# <Tweet id="1766082584285720989">
# <Tweet id="1766082361278751122">
# <Tweet id="1766082297823178826">
# <Tweet id="1766082263350190461">
# <Tweet id="1766082235508347170">
# <Tweet id="1766082126657761357">
# <Tweet id="1766082113189851252">
# <Tweet id="1766082067098669555">
# <Tweet id="1766082048563847290">
# <Tweet id="1766081608304697731">
# <Tweet id="1766081294780502115">
# <Tweet id="1766081244763435382">
# <Tweet id="1766080863408619825">
# <Tweet id="1766080849689321798">
# <Tweet id="1766080834442829847">
# <Tweet id="1766080800985108708">
# <Tweet id="1766080744865288385">
# <Tweet id="1766080341620789371">
# <Tweet id="1766080340588626423">
# <Tweet id="1766080329335410699">
# <Tweet id="1766080025881932042">
# <Tweet id="1766079941819638141">
# <Tweet id="1766079616933126511">
# <Tweet id="1766079490692980962">
# <Tweet id="1766079408220299416">
# <Tweet id="1766079314104320207">
# <Tweet id="1766079200010633673">
# <Tweet id="1766079184848449628">
# <Tweet id="1766079151294013510">
# <Tweet id="1766078975627907072">
# <Tweet id="1766078914554990801">
# <Tweet id="1766078788641738838">

# %%
with open('manipur_tweets.csv', 'w', newline='') as output_csv_file:
    csv_writer = csv.writer(output_csv_file)
    csv_writer.writerow(['id', 'text', 'favorite_count'])    
    for tweet in tweets:
        tweet = client.get_tweet_by_id(tweet.id)
        # Access tweet attributes
        print(
            f'id: {tweet.id}',
            f'text {tweet.text}',
            f'favorite count: {tweet.favorite_count}',
            f'media: {tweet.media}',
            sep='\n'
        )
        csv_writer.writerow([tweet.id, tweet.text, tweet.favorite_count])
# Out:
# id: 1766083001224683683
# text @ArfaatGzn She doesn't know where is manipur
# favorite count: 0
# media: None
# id: 1766082994874269708
# text @RubikaLiyaquat @News18India Manipur wale bhi parivar hain ya bas wo nahi hain?
# favorite count: 0
# media: None
# id: 1766082844911395226
# text Army officers became agniveers...CRPF jawan became a killer..a good police officer became a khalistani..a Police officer kicks Muslims..now army officers kidnapped in Manipur..this is just the deterioration in 2 yrs for our men in uniform..ab aage ka socho!
# favorite count: 0
# media: None
# id: 1766082803937247658
# text Man who has reduced Delhi  police to be beaten and cowardice state Mr @AmitShah is in cabinet coz sycophancy pays and @narendramodi loves it.
# Shah’s incompetency is so glaring from Shaheen Bagh, farmer protests, anti CAA riots, RD riots, Manipur but he still stays.
# favorite count: 0
# media: None
# id: 1766082676123939234
# text @prabhudam @VamsiChandran Hindus will vote based on inflation (petrol, gas and diesel price rise), Manipur issue, electoral bonds scam, farmers protest, unemployment, paper leak, etc. Tamil sanghi clown 🤡
# favorite count: 0
# media: None
# id: 1766082584285720989
# text Manipur has vanished from news debates
# favorite count: 0
# media: None
# id: 1766082361278751122
# text @ndtv The central government seems to have failed Manipur. Crimes committed against tribesmen there are not recognized.
# favorite count: 0
# media: None
# id: 1766082297823178826
# text @nareshchandra_1 @blackwhite01011 Effect of this attitude...
# Attack each and every other community they comes across &amp; wen retaliated, cry victims.
# Got kicked out of Bangladesh, Myanmar &amp; Mizoram bcos of their savage &amp; barbaric nature.
# Now, Manipur 's turn.... https://t.co/8h3I9ZAIIg
# favorite count: 0
# media: [{'display_url': 'pic.twitter.com/8h3I9ZAIIg', 'expanded_url': 'https://twitter.com/Sushindro/status/1766082297823178826/photo/1', 'id_str': '1766082259646558208', 'indices': [273, 296], 'media_key': '3_1766082259646558208', 'media_url_https': 'https://pbs.twimg.com/media/GIJidUJaMAAprZe.jpg', 'type': 'photo', 'url': 'https://t.co/8h3I9ZAIIg', 'ext_media_availability': {'status': 'Available'}, 'features': {'large': {'faces
#
# Wait, I guess Manipur ppl are not his PARIVAR..
# Then it's ok. No worries.
#
# #ManipurViolence
# favorite count: 0
# media: None
# id: 1766082113189851252
# text Once again, an Indian Army officer abducted from his residence in Imphal, Manipur.
# This is the result of giving free hand to radical armed groups &amp; making peace deals with separatists like UNLF-P &amp; not monitoring them.
# #CommunalCM_Biren
# #MeiteiWarCrimes  https://t.co/hYXQpxrEjk
# favorite count: 7
# media: None
# id: 1766082067098669555
# text @BharatiGhosh1 @narendramodi @JPNadda @BJP4India @PMOIndia @BJPMahilaMorcha @AmitShah @BJPCentralMedia Manipur says hi
# favorite count: 0
# media: None
# id: 1766082048563847290
# text ପୁଣି ଜଣେ ଆର୍ମି ଅଫିସରଙ୍କୁ ଘରୁ ଉଠାଇ ନେଲେ #Army #Manipur
# https://t.co/ijbvzLEGpZ
# favorite count: 0
# media: None
# id: 1766081608304697731
# text @MrSinha_ Minnitty ek army officer kidnapped ho gaya Congress ruled Manipur aur tu abhi tak isi par atka hua hai
# favorite count: 0
# media: None
# id: 1766081294780502115
# text The Valley Imphal is plunging into complete anarchy as evident from the daily report of abductions, extortion, kidnapping and all sorts of anti-social activities taking place. When will @narendramodi @AmitShah ji contemplate re-imposition of #AFSPA in the valley Manipur? CM…
# favorite count: 3
# media: None
# id: 1766081244763435382
# text Words that you will never hear from vishwaguru
# Demonetisation
# Black money
# China
# Manipur
# Rapes
# Unemployment
# Inflation
# PMcares
# He is in denial to save himself..but why are we in denial when it's only making us more unsafe !
# favorite count: 5
# media: None
# id: 1766080863408619825
# text @thoichang #MahaShivaratri #Mahashivratri2024 #MahaShivratri_Special #Manipur
# favorite count: 0
# media: None
# id: 1766080849689321798
# text Since #Manipur doesn't belong to modi's family the matter would be erased from domain!
#
# And the COAS would keep silent since he might miss his post retirement job!
#
# Strange times we live in ...
# favorite count: 0
# media: None
# id: 1766080834442829847
# text Cylinders. Cycles. Cash
#
# -The Mighty 49!
#
# -2024: Wo-men For Votes
#
# -#Manipur &amp; #Sandeshkhali for 'Sandesh'
#
# -Only sops, no seats!
#
# -Her vote decides?
#
# #LokSabhaElections | Watch #TheUrbanDebate with @ShreyaDhoundial @ 8 PM https://t.co/PRMNwip1gw
# favorite count: 0
# media: [{'display_url': 'pic.twitter.com/PRMNwip1gw', 'expanded_url': 'https://twitter.com/MirrorNow/status/1766080834442829847/photo/1', 'id_str': '1754502647200264192', 'indices': [227, 250], 'media_key': '16_1754502647200264192', 'media_url_https': 'https://pbs.twimg.com/tweet_video_thumb/GFk-3KPasAAw3Qv.jpg', 'type': 'animated_gif', 'url': 'https://t.co/PRMNwip1gw', 'ext_media_availability': {'status': 'Available'}, 'sizes': {'large': {'h': 720, 'w': 1280, 'resize': 'fit'}, 'medium': {'h': 675, 'w': 1200, 'resize': 'fit'}, 'small': {'h': 383, 'w': 680, 'resize': 'fit'}, 'thumb': {'h': 150, 'w': 150, 'resize': 'crop'}}, 'original_info': {'height': 720, 'width': 1280, 'focus_rects': []}, 'video_info': {'aspect_ratio': [16, 9], 'variants': [{'bitrate': 0, 'content_type': 'video/mp4', 'url': 'https://video.twimg.com/tweet_video/GFk-3KPasAAw3Qv.mp4'}]}}]

# %%
hash_tags = "#KukiMilitant #SaveManipur #Savemeiteis #Ethniccleansing #kukimilitants #kuki #meitei #visitManipur #Kuki_ZoEngineeredViolence #SaveMoreh #SaveManipurSaveIndia #MorehBurning #ManipurFights Back #KukiMilitantvioleteSoO #AbrogateSoO #poppy #illegalImmigration #terror #Sanamahi #7MonthsOfNoInternet #StopTheViolence #MyManipur #Stand4Manipur #ManipurUnderAttack #StopGenocideofMeiteis #lies #genocide #KukiLiesXposed #KukiAtrocites #KukiZoEngineerdManipurConflict #meiteiyouths #KukiWarCrimes #PoppyCultivators #kukinarcoterrorist #Narcokukiterrorist #SavekukiZoTribals #ManipurCrisis #KukiRapist #AssamRifles#lamkatalk #stoppoppycultivators #kukizo #kukizolivesmatter #ManipurPolice #FailedGovernment #manipurisburning #MeiteiMilitant "
hashtags = hash_tags.split()
# print(hashtags)

# %%
tweets = client.search_tweet('#KukiMilitant', 'Latest')
for tweet_id in tweets:
    print(tweet_id)
while True:
    print("More tweets")
    more_tweets = tweets.next()
# Out:
# <Tweet id="1765915216578269251">
# <Tweet id="1765911297038909500">
# <Tweet id="1764602594054267306">
# <Tweet id="1763921640847528148">
# <Tweet id="1763798596783140905">
# <Tweet id="1763609741853589769">
# <Tweet id="1763519890273755610">
# <Tweet id="1763494714983297385">
# <Tweet id="1763488287203921948">
# <Tweet id="1763297268734816692">
# More tweets
# More tweets
# More tweets
# More tweets
# More tweets
# More tweets
# More tweets
# More tweets
# More tweets
# More tweets
# More tweets
# More tweets
# More tweets
# More tweets
# More tweets
# More tweets
# More tweets
# More tweets
# More tweets
# More tweets
# More tweets
# More tweets
# More tweets
# More tweets
# More tweets
# More tweets
# More tweets
# More tweets
# More tweets
# More tweets
# More tweets
# More tweets
# More tweets
# More tweets
# More tweets
# More tweets
# More tweets
# More tweets
# More tweets
# More tweets
# More tweets
# More tweets
# More tweets
# ---------------------------------------------------------------------------
# TooManyRequests                           Traceback (most recent call last)
# Cell In[27], line 6
#       4 while True:
#       5     print("More tweets")
# ----> 6     more_tweets = tweets.next()
#
# File ~/Desktop/Data-Collection/twitter-scraper/.venv/lib/python3.11/site-packages/twikit/utils.py:163, in Result.next(self)
#     161 if self.__fetch_next_result is None:
#     162     return Result([])
# --> 163 return self.__fetch_next_result()
#
# File ~/Desktop/Data-Collection/twitter-scraper/.venv/lib/python3.11/site-packages/twikit/client.py:471, in Client.search_tweet.<locals>.<lambda>()
#     466     user_info = tweet_info['core']['user_results']['result']
#     467     results.append(Tweet(self, tweet_info, User(self, user_info)))
#     469 return Result(
#     470     results,
# --> 471     lambda:self.search_tweet(query, product, count, next_cursor),
#     472     next_cursor
#     473 )
#
# File ~/Desktop/Data-Collection/twitter-scraper/.venv/lib/python3.11/site-packages/twikit/client.py:443, in Client.search_tweet(self, query, product, count, cursor)
#     402 """
#     403 Searches for tweets based on the specified query and
#     404 product type.
#    (...)
#     439 ...
#     440 """
#     441 product = product.capitalize()
# --> 443 response = self._search(query, product, count, cursor)
#     444 instructions = find_dict(response, 'instructions')[0]
#     446 if cursor is None and product == 'Media':
#
# File ~/Desktop/Data-Collection/twitter-scraper/.venv/lib/python3.11/site-packages/twikit/client.py:387, in Client._search(self, query, product, count, cursor)
#     382     variables['cursor'] = cursor
#     383 params = {
#     384     'variables': json.dumps(variables),
#     385     'features': json.dumps(FEATURES)
#     386 }
# --> 387 response = self.http.get(
#     388     Endpoint.SEARCH_TIMELINE,
#     389     params=params,
#     390     headers=self._base_headers
#     391 ).json()
#     393 return response
#
# File ~/Desktop/Data-Collection/twitter-scraper/.venv/lib/python3.11/site-packages/twikit/http.py:51, in HTTPClient.get(self, url, **kwargs)
#      50 def get(self, url, **kwargs) -> httpx.Response:
# ---> 51     return self.request('GET', url, **kwargs)
#
# File ~/Desktop/Data-Collection/twitter-scraper/.venv/lib/python3.11/site-packages/twikit/http.py:42, in HTTPClient.request(self, method, url, **kwargs)
#      40     raise RequestTimeout(message)
#      41 elif status_code == 429:
# ---> 42     raise TooManyRequests(message)
#      43 elif 500 <= status_code < 600:
#      44     raise ServerError(message)
#
# TooManyRequests: status: 429, message: "Rate limit exceeded
# "

# %%
NEXTPAGE = 1

with open('manipur_violence.csv', 'w', newline='') as output_csv_file:
    csv_writer = csv.writer(output_csv_file)
    csv_writer.writerow(['hashtag', 'text', 'favorite_count'])    
    
    for hashtag in hashtags:
        while True:
            try:
                tweets = client.search_tweet(hashtag, 'Latest')
                for tweet in tweets:
                    tweet = client.get_tweet_by_id(tweet.id)
                    csv_writer.writerow([hashtag, tweet.text, tweet.favorite_count])
                    
                for i in range(NEXTPAGE):
                    more_tweets = client.search_tweet(hashtag, 'Latest')
                    for tweet in more_tweets:
                        tweet = client.get_tweet_by_id(tweet.id)
                        csv_writer.writerow([hashtag, tweet.text, tweet.favorite_count])
                
                break
            except twikit.errors.TooManyRequests:
                print("Rate limit exceeded. Waiting for 15 minutes...")
                time.sleep(903)
            except Exception as e:
                print("An error occurred:", e)
                break
# Out:
# Rate limit exceeded. Waiting for 15 minutes...
# ---------------------------------------------------------------------------
# TooManyRequests                           Traceback (most recent call last)
# Cell In[7], line 12
#      11 for tweet in tweets:
# ---> 12     tweet = client.get_tweet_by_id(tweet.id)
#      13     csv_writer.writerow([hashtag, tweet.text, tweet.favorite_count])
#
# File ~/Desktop/Data-Collection/twitter-scraper/.venv/lib/python3.11/site-packages/twikit/client.py:1050, in Client.get_tweet_by_id(self, tweet_id, cursor)
#    1030 """
#    1031 Fetches a tweet by tweet ID.
#    1032
#    (...)
#    1048 <Tweet id="...">
#    1049 """
# -> 1050 response = self._get_tweet_detail(tweet_id, cursor)
#    1052 entries = find_dict(response, 'entries')[0]
#
# File ~/Desktop/Data-Collection/twitter-scraper/.venv/lib/python3.11/site-packages/twikit/client.py:992, in Client._get_tweet_detail(self, tweet_id, cursor)
#     987 params = {
#     988     'variables': json.dumps(variables),
#     989     'features': json.dumps(FEATURES),
#     990     'fieldToggles': json.dumps({'withAuxiliaryUserLabels': False})
#     991 }
# --> 992 response = self.http.get(
#     993     Endpoint.TWEET_DETAIL,
#     994     params=params,
#     995     headers=self._base_headers
#     996 ).json()
#     997 return response
#
# File ~/Desktop/Data-Collection/twitter-scraper/.venv/lib/python3.11/site-packages/twikit/http.py:51, in HTTPClient.get(self, url, **kwargs)
#      50 def get(self, url, **kwargs) -> httpx.Response:
# ---> 51     return self.request('GET', url, **kwargs)
#
# File ~/Desktop/Data-Collection/twitter-scraper/.venv/lib/python3.11/site-packages/twikit/http.py:42, in HTTPClient.request(self, method, url, **kwargs)
#      41 elif status_code == 429:
# ---> 42     raise TooManyRequests(message)
#      43 elif 500 <= status_code < 600:
#
# TooManyRequests: status: 429, message: "Rate limit exceeded
# "
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 24
#      22 except twikit.errors.TooManyRequests:
#      23     print("Rate limit exceeded. Waiting for 15 minutes...")
# ---> 24     time.sleep(15 * 60)
#      25 except Exception as e:
#      26     print("An error occurred:", e)
#
# KeyboardInterrupt:
