# %%
from bs4 import BeautifulSoup
import requests
import re

# %%
def download_pdf(url, name, directory):
    save_path = f"downloaded_pdfs/{directory}/{name}"
    response = requests.get(url)
    if response.status_code == 200:
        with open(save_path, 'wb') as pdf_file:
            pdf_file.write(response.content)
        print(f"PDF downloaded successfully and saved at: {save_path}")
    else:
        print(f"Failed to download PDF. Status code: {response.status_code}")

def fetch_paochelsalaitaret():
    directory = "paochelsalaitaret"
    source = requests.get('http://paochelsalaitaret.net/ebook.php').text
    main = BeautifulSoup(source, 'lxml')
    http_links = main.find_all('a', href=re.compile(r'\.pdf$'))

    for link in http_links:
        url = f"http://paochelsalaitaret.net/{link.get('href')}"
        name = link.get('href').split('/')
        print(url)
        print(name)
        download_pdf(url, name[1], directory)

# %%
fetch_paochelsalaitaret()
# Out:
# http://paochelsalaitaret.net/ebook/shk1.pdf
# ['ebook', 'shk1.pdf']
# http://paochelsalaitaret.net/ebook/shk2.pdf
# ['ebook', 'shk2.pdf']
# http://paochelsalaitaret.net/ebook/shk3.pdf
# ['ebook', 'shk3.pdf']
# http://paochelsalaitaret.net/ebook/kcm.pdf
# ['ebook', 'kcm.pdf']
# http://paochelsalaitaret.net/ebook/pamon.pdf
# ['ebook', 'pamon.pdf']
# http://paochelsalaitaret.net/ebook/bk.pdf
# ['ebook', 'bk.pdf']
# http://paochelsalaitaret.net/ebook/bw.pdf
# ['ebook', 'bw.pdf']
# http://paochelsalaitaret.net/ebook/mb.pdf
# ['ebook', 'mb.pdf']
# http://paochelsalaitaret.net/ebook/mw1.pdf
# ['ebook', 'mw1.pdf']
# http://paochelsalaitaret.net/ebook/mw2.pdf
# ['ebook', 'mw2.pdf']
# http://paochelsalaitaret.net/ebook/mw3.pdf
# ['ebook', 'mw3.pdf']
# http://paochelsalaitaret.net/ebook/nongkalol.pdf
# ['ebook', 'nongkalol.pdf']
# http://paochelsalaitaret.net/ebook/nongsapa.pdf
# ['ebook', 'nongsapa.pdf']
# http://paochelsalaitaret.net/ebook/yek.pdf
# ['ebook', 'yek.pdf']
# http://paochelsalaitaret.net/ebook/meetei.pdf
# ['ebook', 'meetei.pdf']
# http://paochelsalaitaret.net/ebook/dk1.pdf
# ['ebook', 'dk1.pdf']
# http://paochelsalaitaret.net/ebook/dk2.pdf
# ['ebook', 'dk2.pdf']
# http://paochelsalaitaret.net/ebook/dk3.pdf
# ['ebook', 'dk3.pdf']
# http://paochelsalaitaret.net/ebook/puya_n_sc.pdf
# ['ebook', 'puya_n_sc.pdf']
# http://paochelsalaitaret.net/puya/puyaproof.pdf
# ['puya', 'puyaproof.pdf']
# http://paochelsalaitaret.net/puya/puyanf.pdf
# ['puya', 'puyanf.pdf']
# http://paochelsalaitaret.net/puya/puyaw.pdf
# ['puya', 'puyaw.pdf']
# http://paochelsalaitaret.net/puya/puyac.pdf
# ['puya', 'puyac.pdf']
# http://paochelsalaitaret.net/puya/puyab.pdf
# ['puya', 'puyab.pdf']
# http://paochelsalaitaret.net/puya/puyath.pdf
# ['puya', 'puyath.pdf']
# http://paochelsalaitaret.net/ebook/shk1.pdf
# ['ebook', 'shk1.pdf']
# http://paochelsalaitaret.net/ebook/kcm.pdf
# ['ebook', 'kcm.pdf']
# http://paochelsalaitaret.net/ebook/shk2.pdf
# ['ebook', 'shk2.pdf']
# http://paochelsalaitaret.net/ebook/bke.pdf
# ['ebook', 'bke.pdf']
# http://paochelsalaitaret.net/ebook/bw.pdf
# ['ebook', 'bw.pdf']
# http://paochelsalaitaret.net/article/Meeteilon_eba_yadye_27na.pdf
# ['article', 'Meeteilon_eba_yadye_27na.pdf']
# http://paochelsalaitaret.net/article/e1827.pdf
# ['article', 'e1827.pdf']
# http://paochelsalaitaret.net/article/dk70.pdf
# ['article', 'dk70.pdf']
# http://paochelsalaitaret.net/article/will.pdf
# ['article', 'will.pdf']
# http://paochelsalaitaret.net/article/dk36.pdf
# ['article', 'dk36.pdf']
# http://paochelsalaitaret.net/article/dk2.pdf
# ['article', 'dk2.pdf']
# http://paochelsalaitaret.net/article/dk32.pdf
# ['article', 'dk32.pdf']
# http://paochelsalaitaret.net/article/dk50.pdf
# ['article', 'dk50.pdf']
# http://paochelsalaitaret.net/article/dk26.pdf
# ['article', 'dk26.pdf']
# http://paochelsalaitaret.net/article/dk41.pdf
# ['article', 'dk41.pdf']
# http://paochelsalaitaret.net/article/ic.pdf
# ['article', 'ic.pdf']
# http://paochelsalaitaret.net/article/dk68.pdf
# ['article', 'dk68.pdf']
# http://paochelsalaitaret.net/article/dk54.pdf
# ['article', 'dk54.pdf']
# http://paochelsalaitaret.net/article/dk69.pdf
# ['article', 'dk69.pdf']
# http://paochelsalaitaret.net/article/dk701.pdf
# ['article', 'dk701.pdf']
# http://paochelsalaitaret.net/article/dk37.pdf.pdf
# ['article', 'dk37.pdf.pdf']
# http://paochelsalaitaret.net/article/dk58.pdf
# ['article', 'dk58.pdf']
# http://paochelsalaitaret.net/article/dk67.pdf
# ['article', 'dk67.pdf']
# http://paochelsalaitaret.net/article/dk13.pdf
# ['article', 'dk13.pdf']
# http://paochelsalaitaret.net/article/dk42.pdf
# ['article', 'dk42.pdf']
# http://paochelsalaitaret.net/article/dk63.pdf
# ['article', 'dk63.pdf']
# http://paochelsalaitaret.net/article/dk74.pdf
# ['article', 'dk74.pdf']
# http://paochelsalaitaret.net/article/st.pdf
# ['article', 'st.pdf']
# http://paochelsalaitaret.net/article/dk1.pdf
# ['article', 'dk1.pdf']
# http://paochelsalaitaret.net/article/dk64.pdf
# ['article', 'dk64.pdf']
# http://paochelsalaitaret.net/article/dk28.pdf
# ['article', 'dk28.pdf']
# http://paochelsalaitaret.net/article/dk56.pdf
# ['article', 'dk56.pdf']
# http://paochelsalaitaret.net/article/dk71.pdf
# ['article', 'dk71.pdf']
# http://paochelsalaitaret.net/article/dk59.pdf
# ['article', 'dk59.pdf']
# http://paochelsalaitaret.net/article/dk4.pdf
# ['article', 'dk4.pdf']
# http://paochelsalaitaret.net/article/dk17.pdf
# ['article', 'dk17.pdf']
# http://paochelsalaitaret.net/article/dk62.pdf
# ['article', 'dk62.pdf']
# http://paochelsalaitaret.net/article/dk8.pdf
# ['article', 'dk8.pdf']
# http://paochelsalaitaret.net/article/dk21.pdf
# ['article', 'dk21.pdf']
# http://paochelsalaitaret.net/article/notice.pdf
# ['article', 'notice.pdf']
# http://paochelsalaitaret.net/article/meetei.pdf
# ['article', 'meetei.pdf']
# http://paochelsalaitaret.net/article/dk22.pdf
# ['article', 'dk22.pdf']
# http://paochelsalaitaret.net/article/dk47.pdf
# ['article', 'dk47.pdf']
# http://paochelsalaitaret.net/article/dk48.pdf
# ['article', 'dk48.pdf']
# http://paochelsalaitaret.net/article/dk38.pdf
# ['article', 'dk38.pdf']
# http://paochelsalaitaret.net/article/dk30.pdf
# ['article', 'dk30.pdf']
# http://paochelsalaitaret.net/article/dk25.pdf
# ['article', 'dk25.pdf']
# http://paochelsalaitaret.net/article/ningol.pdf
# ['article', 'ningol.pdf']
# http://paochelsalaitaret.net/article/dk45.pdf
# ['article', 'dk45.pdf']
# http://paochelsalaitaret.net/article/dk65.pdf
# ['article', 'dk65.pdf']
# http://paochelsalaitaret.net/article/dk12.pdf
# ['article', 'dk12.pdf']
# http://paochelsalaitaret.net/article/dk29.pdf
# ['article', 'dk29.pdf']
# http://paochelsalaitaret.net/article/dk5.pdf
# ['article', 'dk5.pdf']
# http://paochelsalaitaret.net/article/dk20.pdf
# ['article', 'dk20.pdf']
# http://paochelsalaitaret.net/article/dk23.pdf
# ['article', 'dk23.pdf']
# http://paochelsalaitaret.net/article/dk39.pdf
# ['article', 'dk39.pdf']
# http://paochelsalaitaret.net/article/dk39.pdf
# ['article', 'dk39.pdf']
# http://paochelsalaitaret.net/article/dk40.pdf
# ['article', 'dk40.pdf']
# http://paochelsalaitaret.net/article/pm.pdf
# ['article', 'pm.pdf']
# http://paochelsalaitaret.net/article/puyapanjika.pdf
# ['article', 'puyapanjika.pdf']
# http://paochelsalaitaret.net/article/dk34.pdf
# ['article', 'dk34.pdf']
# http://paochelsalaitaret.net/article/replytoirengbam.pdf
# ['article', 'replytoirengbam.pdf']
# http://paochelsalaitaret.net/article/hodamba.pdf
# ['article', 'hodamba.pdf']
# http://paochelsalaitaret.net/article/dk66.pdf
# ['article', 'dk66.pdf']
# http://paochelsalaitaret.net/article/dk61.pdf
# ['article', 'dk61.pdf']
# http://paochelsalaitaret.net/article/dk60.pdf
# ['article', 'dk60.pdf']
# http://paochelsalaitaret.net/article/dk72.pdf
# ['article', 'dk72.pdf']
# http://paochelsalaitaret.net/article/dk27.pdf
# ['article', 'dk27.pdf']
# http://paochelsalaitaret.net/article/dk51.pdf
# ['article', 'dk51.pdf']
# http://paochelsalaitaret.net/article/dk3.pdf
# ['article', 'dk3.pdf']
# http://paochelsalaitaret.net/article/dk49.pdf
# ['article', 'dk49.pdf']
# http://paochelsalaitaret.net/article/tk.pdf
# ['article', 'tk.pdf']
# http://paochelsalaitaret.net/article/dk33.pdf
# ['article', 'dk33.pdf']
# http://paochelsalaitaret.net/article/suresh.pdf
# ['article', 'suresh.pdf']
# http://paochelsalaitaret.net/article/mb.pdf
# ['article', 'mb.pdf']
# http://paochelsalaitaret.net/article/dk57.pdf
# ['article', 'dk57.pdf']
# http://paochelsalaitaret.net/article/dk43.pdf
# ['article', 'dk43.pdf']
# http://paochelsalaitaret.net/article/dk18.pdf
# ['article', 'dk18.pdf']
# http://paochelsalaitaret.net/article/dk24.pdf
# ['article', 'dk24.pdf']
# http://paochelsalaitaret.net/article/dk31.pdf
# ['article', 'dk31.pdf']
# http://paochelsalaitaret.net/article/dk10.pdf
# ['article', 'dk10.pdf']
# http://paochelsalaitaret.net/article/dk73.pdf
# ['article', 'dk73.pdf']
# http://paochelsalaitaret.net/article/dk46.pdf
# ['article', 'dk46.pdf']
