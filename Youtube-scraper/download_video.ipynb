# %%
import os
from googleapiclient.discovery import build
import pandas as pd
from pytube import YouTube

# %%
api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = "AIzaSyD_s3lu76rpoAt_Ym6WC87-KFFBTxPj3hY"
youtube = build(api_service_name, api_version, developerKey = DEVELOPER_KEY)

# %%
def get_channel_stats(youtube, channel_ids):
    """
    Get channel statistics: title, subscriber count, view count, video count, upload playlist
    Params:
    
    youtube: the build object from googleapiclient.discovery
    channels_ids: list of channel IDs
    
    Returns:
    Dataframe containing the channel statistics for all channels in the provided list: title, subscriber count, view count, video count, upload playlist
    
    """
    all_data = []
    request = youtube.channels().list(
                part='snippet,contentDetails,statistics',
                id=','.join(channel_ids))
    response = request.execute() 
    
    for i in range(len(response['items'])):
        data = dict(channelName = response['items'][i]['snippet']['title'],
                    subscribers = response['items'][i]['statistics']['subscriberCount'],
                    views = response['items'][i]['statistics']['viewCount'],
                    totalVideos = response['items'][i]['statistics']['videoCount'],
                    playlistId = response['items'][i]['contentDetails']['relatedPlaylists']['uploads'])
        all_data.append(data)
    
    return pd.DataFrame(all_data)

# %%
def get_video_ids(youtube, playlist_id):
    """
    Get list of video IDs of all videos in the given playlist
    Params:
    
    youtube: the build object from googleapiclient.discovery
    playlist_id: playlist ID of the channel
    
    Returns:
    List of video IDs of all videos in the playlist
    
    """
    
    request = youtube.playlistItems().list(
                part='contentDetails',
                playlistId = playlist_id,
                maxResults = 50)
    response = request.execute()
    
    video_ids = []
    
    for i in range(len(response['items'])):
        video_ids.append(response['items'][i]['contentDetails']['videoId'])
        
    next_page_token = response.get('nextPageToken')
    more_pages = True
    
    while more_pages:
        if next_page_token is None:
            more_pages = False
        else:
            request = youtube.playlistItems().list(
                        part='contentDetails',
                        playlistId = playlist_id,
                        maxResults = 50,
                        pageToken = next_page_token)
            response = request.execute()
    
            for i in range(len(response['items'])):
                video_ids.append(response['items'][i]['contentDetails']['videoId'])
            
            next_page_token = response.get('nextPageToken')
        
    return video_ids

# %%
def Download(channel, video_id):
    link = "https://www.youtube.com/watch?v={}channel={}".format(video_id,channel)
    youtubeObject = YouTube(link)
    youtubeObject = youtubeObject.streams.get_highest_resolution()
    try:
        print("Starting download")
        youtubeObject.download('./downloads')
    except:
        print("An error has occurred")
    print("Download is completed successfully")

# %%
news_channel_ids = ['UCt4t-jeY85JegMlZ-E5UWtA', #Aaj tak
                   'UCYPvAwZP8pZhSMW8qs7cVCw',  #India Today
                   'UC_gUM8rL-Lrg6O3adPW9K1g',  #Wion
                   'UCRWFSbif-RFENbBrSiez1DA',  #ABP news
                   'UC8dnBi4WUErqYQHZ4PfsLTg',  #Tv9 Kannada
                   ]

music_channel_ids = ['UC0C-w0YjGpqDXGB8IHb662A', #Ed Sheeran
                   'UCqECaJ8Gagnn7YCbPEzWH6g',  #Taylor Swift
                   'UCDPM_n1atn2ijUwHd0NNRQw',  #Coldplay
                   ]

# %%
channel_data = get_channel_stats(youtube, music_channel_ids)
channel_data
# Out:
#     channelName subscribers        views totalVideos                playlistId
# 0      Coldplay    25600000  17760431438         401  UUDPM_n1atn2ijUwHd0NNRQw
# 1    Ed Sheeran    53700000  30847079439         445  UU0C-w0YjGpqDXGB8IHb662A
# 2  Taylor Swift    54400000  31372088899         220  UUqECaJ8Gagnn7YCbPEzWH6g

# %%
for channel in music_channel_ids:
    playlist_id = channel_data.loc[channel_data['channelName']== c, 'playlistId'].iloc[0]
    video_ids = get_video_ids(youtube, playlist_id)
    for video_id in video_ids:
        Download(channel, video_id)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 for channel in music_channel_ids:
# ----> 2     playlist_id = channel_data.loc[channel_data['channelName']== c, 'playlistId'].iloc[0]
#       3     video_ids = get_video_ids(youtube, playlist_id)
#       4     print(video_ids)
#
# NameError: name 'channel_data' is not defined

# %%
channel = "EdSheeran"
videoid = "JGwWNGJdvx8&ab_"
Download(channel, videoid)
# Out:
# Download is completed successfully

# %%
mankibaat_playlist_id = "PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7"
video_id = get_video_ids(youtube, mankibaat_playlist_id)
# Out:
# ['MEeBdca7Do0',
#  'SAyhnHl_5TU',
#  'fq6fAaS6A4c',
#  '2C9Hadeoi3E',
#  'G52NO-QE6Fk',
#  'ksd5jUpGWv4',
#  'kovi9FDfUzs',
#  'm3qHlzv4ock',
#  '7YKwz82KEmI',
#  'mZ0H1gyQQyc',
#  'QxLum4JMQWQ',
#  'ox8IkNhEZ4g',
#  'SNlZV4eg7Bs',
#  '2BUhYFdEj98',
#  'dhdbhiPoxnc',
#  'JjxjNyCiErk',
#  '_l9qt7zhciI',
#  'rAyreycNR_k',
#  'l4ZhHhtBmVg',
#  'K29X-cPZXh8',
#  'iDQN9qL8OD4',
#  'RTgrcsms9vA',
#  'xNR2Rk6ps24',
#  'lgBrbkmYixw',
#  'gaw8u_QHJEI',
#  '3ZcOo_ThdTw',
#  'TC2OrrPYMsw',
#  'Rp_FY6y4cmw',
#  'Bw3PxD-Z1MY',
#  'zt_STVCmDrQ',
#  'UWULJ0eWBl4',
#  'tmqm_qES_4Y',
#  'gWLTdEKzcI0',
#  'ROgvnXLjPsI',
#  'Pi_FVeGZF-o',
#  'OPVtKXoQaEo',
#  'XojZYteYWEo',
#  'XojZYteYWEo',
#  'ZQbNLgOOVXw',
#  'ez3Z6zRj1Ts',
#  'tvSHcLdlfMU',
#  'sib1AnU1az8',
#  'WaVZtxEMmeo',
#  'yn-gmDrzaD0',
#  '82pExD6tHLg',
#  'TbmW4KxHqlc',
#  'Salz2CWPx_I',
#  'BwoPImUk3Kg',
#  'nFYg2wljnyM',
#  'KUEL_-YcZ9k',
#  'MfaM8jtLEkU',
#  't3lhdsxok74',
#  '0oqKtwXQZ44',
#  'DaMUTP609rI',
#  'G8eS3jgbzeU',
#  '8iRreea6Qh4',
#  '24OKbzNoLgw',
#  'Qziq5m70z9Y',
#  'HZnpRGjyOZ0',
#  'xwi5lUuXOOc',
#  'mGeWjur7R6o',
#  'ECGOVODYy6E',
#  'xyl-zwovOyE',
#  'pGrAtf4rwLY',
#  '8iXtf-0qAcw',
#  'SNrPm5Kg-pA',
#  'gphlJ12JjSM',
#  'b7p7WaBxU6Y',
#  'qJR2eT3c9xY',
#  'Tt398m4nXV4',
#  '53dib7yEkFQ',
#  'xJv4c0-XnLM',
#  'togOe2daRmw',
#  'T5gmpRXrwEs',
#  '4qd1YteRx7M',
#  'fTrc9HtHJzQ',
#  '-EiZpfjuWnU',
#  'C79C6TMidY0',
#  'S2_kEqmwMtM',
#  '2TbCDHKCvRc',
#  '8TcQp7W4xgg',
#  'GK97E1BICnU',
#  'AISOdT6aqQg',
#  'BN9Fs2l2PmQ',
#  'R0oAFIHdJds',
#  '2TVaUP9tWyM',
#  '-MCNXzlkEJk',
#  'qYojh752U2w',
#  'm25RYModjvo',
#  'nDXc-kJd9yc',
#  '0Gal-rIZwDs',
#  'L3YIaReKUZg']

# %%
vid = pd.Series(video_id)
vid.to_csv('mankibaat_video_ids.csv', index=False)

# %%
c = "SansadTV"
v = "MEeBdca7Do0"
p = "PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7"
link = "https://www.youtube.com/watch?v={}&list={}&ab_channel={}".format(v,p,c)
print(link)
# Out:
# https://www.youtube.com/watch?v=MEeBdca7Do0&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV

# %%
vi = pd.read_csv("mankibaat_video_ids.csv")
vi
# Out:
#       video_ids
# 0   MEeBdca7Do0
# 1   SAyhnHl_5TU
# 2   fq6fAaS6A4c
# 3   2C9Hadeoi3E
# 4   G52NO-QE6Fk
# ..          ...
# 87  qYojh752U2w
# 88  m25RYModjvo
# 89  nDXc-kJd9yc
# 90  0Gal-rIZwDs
# 91  L3YIaReKUZg
#
# [92 rows x 1 columns]

# %%
for i in vi.index:
#     print(vi.loc[i,"video_ids"])
    link = "https://www.youtube.com/watch?v={}&list={}&ab_channel={}".format(vi.loc[i,"video_ids"],p,c)
    print(link)
# Out:
# https://www.youtube.com/watch?v=MEeBdca7Do0&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=SAyhnHl_5TU&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=fq6fAaS6A4c&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=2C9Hadeoi3E&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=G52NO-QE6Fk&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=ksd5jUpGWv4&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=kovi9FDfUzs&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=m3qHlzv4ock&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=7YKwz82KEmI&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=mZ0H1gyQQyc&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=QxLum4JMQWQ&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=ox8IkNhEZ4g&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=SNlZV4eg7Bs&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=2BUhYFdEj98&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=dhdbhiPoxnc&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=JjxjNyCiErk&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=_l9qt7zhciI&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=rAyreycNR_k&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=l4ZhHhtBmVg&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=K29X-cPZXh8&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=iDQN9qL8OD4&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=RTgrcsms9vA&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=xNR2Rk6ps24&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=lgBrbkmYixw&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=gaw8u_QHJEI&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=3ZcOo_ThdTw&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=TC2OrrPYMsw&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=Rp_FY6y4cmw&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=Bw3PxD-Z1MY&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=zt_STVCmDrQ&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=UWULJ0eWBl4&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=tmqm_qES_4Y&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=gWLTdEKzcI0&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=ROgvnXLjPsI&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=Pi_FVeGZF-o&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=OPVtKXoQaEo&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=XojZYteYWEo&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=XojZYteYWEo&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=ZQbNLgOOVXw&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=ez3Z6zRj1Ts&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=tvSHcLdlfMU&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=sib1AnU1az8&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=WaVZtxEMmeo&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=yn-gmDrzaD0&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=82pExD6tHLg&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=TbmW4KxHqlc&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=Salz2CWPx_I&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=BwoPImUk3Kg&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=nFYg2wljnyM&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=KUEL_-YcZ9k&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=MfaM8jtLEkU&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=t3lhdsxok74&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=0oqKtwXQZ44&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=DaMUTP609rI&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=G8eS3jgbzeU&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=8iRreea6Qh4&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=24OKbzNoLgw&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=Qziq5m70z9Y&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=HZnpRGjyOZ0&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=xwi5lUuXOOc&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=mGeWjur7R6o&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=ECGOVODYy6E&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=xyl-zwovOyE&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=pGrAtf4rwLY&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=8iXtf-0qAcw&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=SNrPm5Kg-pA&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=gphlJ12JjSM&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=b7p7WaBxU6Y&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=qJR2eT3c9xY&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=Tt398m4nXV4&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=53dib7yEkFQ&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=xJv4c0-XnLM&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=togOe2daRmw&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=T5gmpRXrwEs&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=4qd1YteRx7M&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=fTrc9HtHJzQ&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=-EiZpfjuWnU&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=C79C6TMidY0&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=S2_kEqmwMtM&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=2TbCDHKCvRc&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=8TcQp7W4xgg&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=GK97E1BICnU&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=AISOdT6aqQg&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=BN9Fs2l2PmQ&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=R0oAFIHdJds&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=2TVaUP9tWyM&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=-MCNXzlkEJk&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=qYojh752U2w&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=m25RYModjvo&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=nDXc-kJd9yc&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=0Gal-rIZwDs&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
# https://www.youtube.com/watch?v=L3YIaReKUZg&list=PLVOgwA_DiGzotAXVMDT50J2fp9w8ASRC7&ab_channel=SansadTV
